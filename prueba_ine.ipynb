# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %%
ine = pd.read_csv(r"C:/Users/Miboo/Desktop/Bootcamp/Proyecto_EDA/prueba_ine2.csv", sep=",", encoding="latin1")
ine
# Out:
#                        Variables   1975   1976   1977   1978   1979   1980  \
# 0              Total_Nacimientos  39646  41100  38806  35657  31835  28812
# 1         Nac_Esp_Todaslasedades    NaN    NaN    NaN    NaN    NaN    NaN
# 2         Nac_Esp_Menosde15anios    NaN    NaN    NaN    NaN    NaN    NaN
# 3             Nac_Esp_15a19anios    NaN    NaN    NaN    NaN    NaN    NaN
# 4             Nac_Esp_20a24anios    NaN    NaN    NaN    NaN    NaN    NaN
# ..                           ...    ...    ...    ...    ...    ...    ...
# 394         Pob_Mujeres_96_anios
# 395         Pob_Mujeres_97_anios
# 396         Pob_Mujeres_98_anios
# 397         Pob_Mujeres_99_anios
# 398  Pob_Mujeres_100_y_mas_anios
#
#       1981   1982   1983  ...   2016   2017   2018   2019   2020   2021  \
# 0    27255  25670  23920  ...  18247  17077  16100  15449  14743  14276
# 1      NaN    NaN    NaN  ...  15156  14102  12920  12127  11452  11215
# ...

# %%
vaers["VAERS_ID"].unique
# Out:
# <bound method Series.unique of 0         791393
# 1         791393
# 2         791393
# 3         791393
# 4         791747
#           ...
# 49035    2880305
# 49036    2880306
# 49037    2880307
# 49038    2880308
# 49039    2883144
# Name: VAERS_ID, Length: 49040, dtype: int64>

# %%
# Out:
# Total de reportes adversos: 40285

# %%
# Seleccionar columnas de síntomas
cols = ["SYMPTOM1", "SYMPTOM2", "SYMPTOM3", "SYMPTOM4", "SYMPTOM5"]

# Pasar de formato ancho a largo
sintomas = (
    vaers[cols]
    .melt(value_name="symptom")["symptom"]
    .dropna()
)

# Frecuencias absolutas
frecuencias = sintomas.value_counts()

# Convertir a DataFrame
frecuencias_df = frecuencias.reset_index()
frecuencias_df.columns = ["Efecto_adverso", "Frecuencia"]

# Mostrar resultados
print(frecuencias_df.head(20))
# Out:
#                                        Efecto_adverso  Frecuencia
# 0                                    No adverse event        5369
# 1                                 Injection site pain        3057
# 2                             Injection site erythema        3036
# 3                                                Pain        2807
# 4                                             Pyrexia        2632
# 5                             Extra dose administered        2526
# 6                             Injection site swelling        2421
# 7                                   Pain in extremity        2311
# 8                                                Rash        2093
# 9                                             Fatigue        2020
# 10                                          Dizziness        2006
# 11                                           Headache        1997
# 12  Product administered to patient of inappropria...        1873
# ...
